# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('second.csv')
print(d)
# Out:
#       Date  page view  avg. time spent (min)  Bpunce rate   scroll depth  CTR
# 0  1-10-24       2000                    3.8            50            70  4.5
# 1  2-10-24       1800                    4.0            45            75  5.2
# 2  3-10-24       2100                    3.5            55            65  3.8
# 3  4-10-24       2500                    4.2            42            80  6.0
# 4  5-10-24       2300                    4.5            40            82  5.8

# %%
date = data['Date']
avg_time_spent= data['avg. time spent (min)']
user_retention = data['page view']

plt.figure(figsize=(10, 6))
plt.plot(date,user_retention ,marker='o', label=' avg_time_spent', color='r')
plt.plot(date,user_retention , marker='s', label='page view', color='b')
plt.title(' avg. time spent and User Retention for Refund High School Chapters 22-30')
plt.xlabel('Date')
plt.ylabel('Percentage (%)')
plt.xticks(rotation=45)
plt.legend()

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
date = data['Date']
depth = data['scroll depth']
ctr= data['CTR']
bar_width = 0.35
index = np.arange(len(date))

plt.figure(figsize=(10, 6))
plt.bar(index, depth, bar_width, label='depth', color='r')
plt.bar(index + bar_width, ctr, bar_width, label='ctr', color='b')
plt.xlabel('Date')
plt.ylabel('CTR')
plt.title('Bounce Rate and User Retention for Refund High School Chapters 22-30')
plt.xticks(index + bar_width / 2, date, rotation=45)
plt.legend()
plt.grid(True, axis='y')
plt.tight_layout()
plt.show()
